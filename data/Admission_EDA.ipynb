# %%
import pandas as pd

# Import all three datasets
admissions_df = pd.read_csv('Data/IPEDS Admissions Data 2019-2024.csv')
completers_df = pd.read_csv('Data/IPEDS Completers Data 2019-2024.csv')
enrollment_df = pd.read_csv('Data/IPEDS Enrollment Data 2019-2024.csv')

# %%
admissions_df
# Out:
#        Year  UNITID Institution name alias Institution (entity) name  \
# 0      2021  100654                   AAMU  Alabama A & M University
# 1      2019  100654                   AAMU  Alabama A & M University
# 2      2020  100654                   AAMU  Alabama A & M University
# 3      2022  100654                   AAMU  Alabama A & M University
# 4      2023  100654                   AAMU  Alabama A & M University
# ...     ...     ...                    ...                       ...
# 11895  2021  164641                    NaN                       NaN
# 11896  2019  164641                    NaN                       NaN
# 11897  2020  164641                    NaN                       NaN
# 11898  2022  164641                    NaN                       NaN
# 11899  2019  448840                    NaN                       NaN
#
#       Street address or post office box City location of institution  \
# ...

# %%
completers_df
# Out:
#        Year  UNITID     Table Names  \
# 0      2019  100654  c2019_c_rv.csv
# 1      2019  100654  c2019_c_rv.csv
# 2      2019  100654  c2019_c_rv.csv
# 3      2019  100663  c2019_c_rv.csv
# 4      2019  100663  c2019_c_rv.csv
# ...     ...     ...             ...
# 95786  2022  498571  c2022_c_rv.csv
# 95787  2022  498571  c2022_c_rv.csv
# 95788  2022  498571  c2022_c_rv.csv
# 95789  2022  498571  c2022_c_rv.csv
# 95790  2022  498571  c2022_c_rv.csv
#
#                                         Award Level code  Grand total  \
# 0                                      Bachelor's degree          560
# 1                                        Master's degree          244
# 2                                        Doctor's degree            6
# 3      Award of at least 1 but less than 4 academic y...           76
# 4                                      Bachelor's degree         2523
# ...                                                  ...          ...
# ...

# %%
enrollment_df
# Out:
#         Year  UNITID Level and degree/certificate-seeking status of student  \
# 0       2024  115001            Part-time students, Undergraduate total
# 1       2024  115001  Part-time students, Undergraduate, Degree/cert...
# 2       2024  115001  Part-time students, Undergraduate, Degree/cert...
# 3       2024  115001  Part-time students, Undergraduate, Degree/cert...
# 4       2024  115001  Part-time students, Undergraduate, Non-degree/...
# ...      ...     ...                                                ...
# 373836  2022  216074                  All students, Undergraduate total
# 373837  2022  216074  All students, Undergraduate, Degree/certificat...
# 373838  2022  216074  All students, Undergraduate, Other degree/cert...
# 373839  2022  216074  All students, Undergraduate, Other degree/cert...
# 373840  2022  216074  All students, Undergraduate, Other degree/cert...
#
#        Undergraduate or graduate level of student  \
# ...

# %%
tx_admissions = admissions_df[admissions_df['State abbreviation'] == 'TX']
print(f"Admissions Data: {len(tx_admissions)} Texas schools")
print(f"Unique institutions: {tx_admissions['Institution (entity) name'].nunique()}\n")
# Out:
# Admissions Data: 529 Texas schools
# Unique institutions: 94

# %%
txst_admissions = admissions_df[admissions_df['Institution (entity) name'].contains('Texas State', case=False, na=False)]
txst_admissions
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/v8/lrp1j76n0s3011q783ywnvvm0000gn/T/ipykernel_31681/2055011568.py in ?()
# ----> 1 txst_admissions = admissions_df[admissions_df['Institution (entity) name'].contains('Texas State', case=False, na=False)]
#       2 txst_admissions
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'contains'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

txst_completers = completers_df[completers_df['Latitude location of institution'] == 29.888885]
txst_enrollment = enrollment_df[enrollment_df['Latitude location of institution'] == 29.888885]

print("TXST Data Overview:")
print(f"Admissions records: {len(txst_admissions)}")
print(f"Completers records: {len(txst_completers)}")
print(f"Enrollment records: {len(txst_enrollment)}")
# Out:
# TXST Data Overview:
# Admissions records: 6
# Completers records: 24
# Enrollment records: 68

# %%
txst_admissions
# Out:
#       Year  UNITID                             Institution name alias  \
# 8571  2021  228459  Texas State|Texas State University-San Marcos|...
# 8572  2019  228459  Texas State|Texas State University-San Marcos|...
# 8573  2020  228459  Texas State|Texas State University-San Marcos|...
# 8574  2022  228459  Texas State|Texas State University-San Marcos|...
# 8575  2023  228459  Texas State|Texas State University-San Marcos|...
# 8576  2024  228459  Texas State|Texas State University-San Marcos|...
#
#      Institution (entity) name Street address or post office box  \
# 8571    Texas State University                 601 University Dr
# 8572    Texas State University                 601 University Dr
# 8573    Texas State University                 601 University Dr
# 8574    Texas State University                 601 University Dr
# 8575    Texas State University                 601 University Dr
# 8576    Texas State University                 601 University Dr
#
# ...

# %%
txst_completers
# Out:
#        Year  UNITID     Table Names  \
# 9636   2019  228459  c2019_c_rv.csv
# 9637   2019  228459  c2019_c_rv.csv
# 9638   2019  228459  c2019_c_rv.csv
# 9639   2019  228459  c2019_c_rv.csv
# 25562  2023  228459     c2023_c.csv
# 25563  2023  228459     c2023_c.csv
# 25564  2023  228459     c2023_c.csv
# 25565  2023  228459     c2023_c.csv
# 41666  2024  228459     c2024_c.csv
# 41667  2024  228459     c2024_c.csv
# 41668  2024  228459     c2024_c.csv
# 41669  2024  228459     c2024_c.csv
# 57649  2021  228459  c2021_c_rv.csv
# 57650  2021  228459  c2021_c_rv.csv
# 57651  2021  228459  c2021_c_rv.csv
# 57652  2021  228459  c2021_c_rv.csv
# 73568  2020  228459  c2020_c_rv.csv
# 73569  2020  228459  c2020_c_rv.csv
# 73570  2020  228459  c2020_c_rv.csv
# 73571  2020  228459  c2020_c_rv.csv
# 89713  2022  228459  c2022_c_rv.csv
# 89714  2022  228459  c2022_c_rv.csv
# 89715  2022  228459  c2022_c_rv.csv
# 89716  2022  228459  c2022_c_rv.csv
#
# ...

# %%
txst_enrollment
# Out:
#         Year  UNITID Level and degree/certificate-seeking status of student  \
# 75171   2024  228459                                 All students total
# 75172   2024  228459                  All students, Undergraduate total
# 75173   2024  228459  All students, Undergraduate, Degree/certificat...
# 75174   2024  228459  All students, Undergraduate, Other degree/cert...
# 75175   2024  228459  All students, Undergraduate, Other degree/cert...
# ...      ...     ...                                                ...
# 277353  2020  228459  Part-time students, Undergraduate, Degree/cert...
# 277354  2020  228459  Part-time students, Undergraduate, Degree/cert...
# 277355  2020  228459  Part-time students, Undergraduate, Degree/cert...
# 277356  2020  228459  Part-time students, Undergraduate, Other degre...
# 277357  2020  228459  Part-time students, Undergraduate, Other degre...
#
#        Undergraduate or graduate level of student  \
# ...
